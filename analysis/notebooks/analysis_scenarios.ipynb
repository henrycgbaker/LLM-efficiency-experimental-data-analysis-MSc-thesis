# %%
import pandas as pd
import re
import os
import matplotlib.pyplot as plt
from IPython.display import display
import warnings
warnings.simplefilter('always')
import importlib
from matplotlib import cm

from scripts.a_data_loading_cleaning import run_load_clean_diagnose_data

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Data Loading & Cleaning

# %%
csv_path = f"results/scenarios_results.csv"
df = run_load_clean_diagnose_data(csv_path)
# Out:
# ✅ Total generated tokens value is constant: 16384
# Original distribution:
# total_generated_tokens
# 16384    16
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Round 1: Verfifying FLOPs on raw df
# NB: FLOPs values are NOT constant: [52638582308864 20248623316992]
# Original distribution:
# flops
# 20248623316992     6
# 52638582308864    10
# Name: count, dtype: int64
#
# Dominant FLOPs value: 52638582308864
# - Affected rows count: 6
# - Affected row indices: [1, 2, 3, 4, 5, 6]
# - Affected configs: ['A1_Single_GPU', 'R5_Tail_SingleGPU_Greedy', 'R6_Tail_DualGPU_TopP', 'R1_Ultralow_SingleGPU_Greedy', 'R2_Ultralow_DualGPU_TopP', 'A4_Parallel_Exploit']
# ----------------------------------------------------------------------------------------------------
# FLOP Differentiators:
# Round 2: Verfifying FLOPs on corrected df
# NB: FLOPs values are NOT constant: [1.69499710e+13 5.26385823e+13]
# Original distribution:
# flops
# 1.694997e+13    8
# 5.263858e+13    8
# Name: count, dtype: int64
#
# Dominant FLOPs value: 16949970993152.0
# - Affected rows count: 8
# - Affected row indices: [8, 9, 10, 11, 12, 13, 14, 15]
# - Affected configs: ['A1_Single_GPU', 'R2_Ultralow_DualGPU_TopP', 'R1_Ultralow_SingleGPU_Greedy', 'R5_Tail_SingleGPU_Greedy', 'A2_2_GPU', 'R6_Tail_DualGPU_TopP', 'A4_Parallel_Exploit', 'A3_Quantisation_Focus']
# ----------------------------------------------------------------------------------------------------
# ✅ FLOPs are unique per model
# ----------------------------------------------------------------------------------------------------
# cyles present: [1]
# /Users/henrybaker/repositories/thesis_analysis/scripts/a_data_loading_cleaning.py:611: UserWarning: NB: FLOPs values are NOT constant: [52638582308864 20248623316992]
#   if not verify_flops(df):
# /Users/henrybaker/repositories/thesis_analysis/scripts/a_data_loading_cleaning.py:621: UserWarning: NB: FLOPs values are NOT constant: [1.69499710e+13 5.26385823e+13]
#   verify_flops(df)

# %% [markdown]
# # Basic understanding on contents

# %%
print(f"number of observation: {len(df)}")
print(f"number of scenarios: {len(df['config_name'].unique())}")
print(f"distribution of scenarios:{df['config_name'].value_counts()}")
# Out:
# number of observation: 16
# number of scenarios: 8
# distribution of scenarios:config_name
# A3_Quantisation_Focus           2
# A1_Single_GPU                   2
# R5_Tail_SingleGPU_Greedy        2
# R6_Tail_DualGPU_TopP            2
# R1_Ultralow_SingleGPU_Greedy    2
# R2_Ultralow_DualGPU_TopP        2
# A4_Parallel_Exploit             2
# A2_2_GPU                        2
# Name: count, dtype: int64

# %%
cols_to_describe = [
    'total_energy_kwh',
    'total_inference_time_sec',
    'average_latency_ms_per_batch',
    'throughput_queries_per_sec',
    'throughput_tokens_per_sec',
    'cpu_energy_total',
    'gpu_energy_total',
    'flops_per_token',
    'energy_per_token_kwh',
    'divergence_energy_flops'
]

df[cols_to_describe].describe()
# Out:
#        total_energy_kwh  total_inference_time_sec  \
# count         16.000000                 16.000000
# mean           0.012984                115.163893
# std            0.020289                164.480715
# min            0.000530                  3.187716
# 25%            0.001665                  8.089505
# 50%            0.004347                 34.599849
# 75%            0.013675                131.592796
# max            0.078608                474.884436
#
#        average_latency_ms_per_batch  throughput_queries_per_sec  \
# count                     16.000000                   16.000000
# mean                    4252.016592                    9.940071
# std                     1707.080154                   11.430864
# min                     2185.761334                    0.269539
# 25%                     3419.967402                    1.282290
# 50%                     3714.911230                    5.976985
# 75%                     5090.391718                   15.846543
# max                     8265.675273                   40.154142
#
#        throughput_tokens_per_sec  cpu_energy_total  gpu_energy_total  \
# count                  16.000000         16.000000         16.000000
# mean                 1272.329107          0.005331          0.007620
# std                  1463.150574          0.008102          0.012452
# min                    34.501025          0.000154          0.000345
# 25%                   164.133057          0.000409          0.001080
# 50%                   765.054060          0.001392          0.003226
# 75%                  2028.357548          0.005917          0.008179
# max                  5139.730233          0.028514          0.049893
#
#        flops_per_token  energy_per_token_kwh  divergence_energy_flops
# count     1.600000e+01          1.600000e+01             1.600000e+01
# mean      2.123674e+09          7.925069e-07             4.187923e-16
# std       1.124849e+09          1.238351e-06             6.124884e-16
# min       1.034544e+09          3.234939e-08             2.046611e-17
# 25%       1.034544e+09          1.016496e-07             6.625976e-17
# 50%       2.123674e+09          2.653297e-07             1.730314e-16
# 75%       3.212804e+09          8.346319e-07             4.899503e-16
# max       3.212804e+09          4.797841e-06             2.202050e-15

# %%
# set colours
all_models = sorted(set(df['model']))
n = len(all_models)

# base colormaps
cmap_energy     = cm.get_cmap('Blues')
cmap_throughput = cm.get_cmap('Reds')

# sample only from the mid→dark part of each map
energy_colors     = [cmap_energy(0.5 + 0.5 * i/(n-1)) for i in range(n)]
throughput_colors = [cmap_throughput(0.5 + 0.2 * i/(n-1)) for i in range(n)]

MODEL_COLOURS = {
    m: {
        'energy':     energy_colors[i],
        'throughput': throughput_colors[i]
    }
    for i, m in enumerate(all_models)
}
# Out:
# /var/folders/9b/zwzkyxhs7h7759872hzp3mz80000gn/T/ipykernel_75676/3422303312.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap_energy     = cm.get_cmap('Blues')
# /var/folders/9b/zwzkyxhs7h7759872hzp3mz80000gn/T/ipykernel_75676/3422303312.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap_throughput = cm.get_cmap('Reds')

# %%
import scripts.b_exploratory_data_analysis as eda
importlib.reload(eda)

#eda.plot_all_diagnostics(df, MODEL_COLOURS=MODEL_COLOURS)
# Out:
# <module 'scripts.b_exploratory_data_analysis' from '/Users/henrybaker/repositories/thesis_analysis/scripts/b_exploratory_data_analysis.py'>

# %% [markdown]
# # Basic stats

# %%
from scripts.f_scenario_analysis import get_descriptive_stats
get_descriptive_stats(df)
# Out:
# Models: ['Llama-3.2-1B', 'Llama-3.2-3B']
#
# --- Llama-3.2-1B (raw data) ---
# Max mean energy: 0.0000 kWh @ R2_Ultralow_DualGPU_TopP
# Min mean energy: 0.0000 kWh @ A1_Single_GPU
# - Energy reduction (worst→best): 98.58%
# - Range vs. mean of means: 427.54%
# - Range vs. min baseline: 6942.23%
#
# Normalized to min baseline:
#                  config_name  norm_to_min  diff_to_min_pct
#                A1_Single_GPU     1.000000         0.000000
#                     A2_2_GPU     3.426802         2.426802
#        A3_Quantisation_Focus     1.098396         0.098396
#          A4_Parallel_Exploit     6.867034         5.867034
# R1_Ultralow_SingleGPU_Greedy    26.029759        25.029759
#     R2_Ultralow_DualGPU_TopP    70.422277        69.422277
#     R5_Tail_SingleGPU_Greedy     5.550543         4.550543
#         R6_Tail_DualGPU_TopP    15.505757        14.505757
#
# Variability & distribution:
#  Count: 8
#  Std dev: 0.0000 kWh (144.62% of mean)
#  Quartiles (25% / 50% / 75%): 0.0000, 0.0000, 0.0000
#  IQR: 0.0000
#  Skewness: 0.00, Kurtosis: 0.00
# ----
#
# --- Llama-3.2-1B (outliers removed (1.5×IQR)) ---
# Max mean energy: 0.0000 kWh @ R1_Ultralow_SingleGPU_Greedy
# Min mean energy: 0.0000 kWh @ A1_Single_GPU
# - Energy reduction (worst→best): 96.16%
# - Range vs. mean of means: 294.58%
# - Range vs. min baseline: 2502.98%
#
# Normalized to min baseline:
#                  config_name  norm_to_min  diff_to_min_pct
#                A1_Single_GPU     1.000000         0.000000
#                     A2_2_GPU     3.426802         2.426802
#        A3_Quantisation_Focus     1.098396         0.098396
#          A4_Parallel_Exploit     6.867034         5.867034
# R1_Ultralow_SingleGPU_Greedy    26.029759        25.029759
#     R5_Tail_SingleGPU_Greedy     5.550543         4.550543
#         R6_Tail_DualGPU_TopP    15.505757        14.505757
#
# Variability & distribution:
#  Count: 7
#  Std dev: 0.0000 kWh (107.92% of mean)
#  Quartiles (25% / 50% / 75%): 0.0000, 0.0000, 0.0000
#  IQR: 0.0000
#  Skewness: 0.00, Kurtosis: 0.00
# ----
#
# --- Llama-3.2-3B (raw data) ---
# Max mean energy: 0.0000 kWh @ R2_Ultralow_DualGPU_TopP
# Min mean energy: 0.0000 kWh @ A1_Single_GPU
# - Energy reduction (worst→best): 98.63%
# - Range vs. mean of means: 446.53%
# - Range vs. min baseline: 7196.70%
#
# Normalized to min baseline:
#                  config_name  norm_to_min  diff_to_min_pct
#                A1_Single_GPU     1.000000         0.000000
#                     A2_2_GPU     3.757318         2.757318
#        A3_Quantisation_Focus     1.125924         0.125924
#          A4_Parallel_Exploit     8.428648         7.428648
# R1_Ultralow_SingleGPU_Greedy    24.686781        23.686781
#     R2_Ultralow_DualGPU_TopP    72.966976        71.966976
#     R5_Tail_SingleGPU_Greedy     4.313106         3.313106
#         R6_Tail_DualGPU_TopP    12.655737        11.655737
#
# Variability & distribution:
#  Count: 8
#  Std dev: 0.0000 kWh (150.56% of mean)
#  Quartiles (25% / 50% / 75%): 0.0000, 0.0000, 0.0000
#  IQR: 0.0000
#  Skewness: 0.00, Kurtosis: 0.00
# ----
#
# --- Llama-3.2-3B (outliers removed (1.5×IQR)) ---
# Max mean energy: 0.0000 kWh @ R1_Ultralow_SingleGPU_Greedy
# Min mean energy: 0.0000 kWh @ A1_Single_GPU
# - Energy reduction (worst→best): 95.95%
# - Range vs. mean of means: 296.26%
# - Range vs. min baseline: 2368.68%
#
# Normalized to min baseline:
#                  config_name  norm_to_min  diff_to_min_pct
#                A1_Single_GPU     1.000000         0.000000
#                     A2_2_GPU     3.757318         2.757318
#        A3_Quantisation_Focus     1.125924         0.125924
#          A4_Parallel_Exploit     8.428648         7.428648
# R1_Ultralow_SingleGPU_Greedy    24.686781        23.686781
#     R5_Tail_SingleGPU_Greedy     4.313106         3.313106
#         R6_Tail_DualGPU_TopP    12.655737        11.655737
#
# Variability & distribution:
#  Count: 7
#  Std dev: 0.0000 kWh (105.65% of mean)
#  Quartiles (25% / 50% / 75%): 0.0000, 0.0000, 0.0000
#  IQR: 0.0000
#  Skewness: 0.00, Kurtosis: 0.00
# ----

# %%
(df['energy_per_token_kwh'] / df['energy_per_token_kwh'].mean()).plot(
    kind='hist',
    bins=50,
    title='Distribution of Normalised Energy per Token',
    xlabel='Energy per Token (normalised by mean) \n"How many times bigger (or smaller) is this value than the average?"',
    ylabel='Frequency'
)
# Out:
# <Axes: title={'center': 'Distribution of Normalised Energy per Token'}, xlabel='Energy per Token (normalised by mean) \n"How many times bigger (or smaller) is this value than the average?"', ylabel='Frequency'>

# %% [markdown]
# # Absolute Numbers

# %%
from scripts.f_scenario_analysis import compare_energy_to_appliances
compare_energy_to_appliances(df)
# Out:
# == ASSUMING AVERAGE LENGTH: 300 TOKENS ==
# Models: ['Llama-3.2-1B', 'Llama-3.2-3B']
#
# === Model: Llama-3.2-1B ===
# -- Scenario: Full config means (8 configs) --
# Overall ratio (max/min): 70.42
# # responses to match appliance (worst/best/diff/mean):
#     iPhone_charge: worst 21.95, best 1545.62, diff 22.26, mean 95.19
#     MacBook_charge: worst 117.06, best 8243.33, diff 118.74, mean 507.67
#     wifi_router_24h: worst 351.17, best 24729.99, diff 356.23, mean 1523.01
#     streaming_1hr: worst 877.92, best 61824.97, diff 890.56, mean 3807.53
#     google_search: worst 0.44, best 30.91, diff 0.45, mean 1.90
#     kettle: worst 109.74, best 7728.12, diff 111.32, mean 475.94
#     shower: worst 2311.85, best 162805.75, diff 2345.15, mean 10026.48
#
# -- Scenario: Without outlier configs (8 configs) --
# Overall ratio (max/min): 70.42
# # responses to match appliance (worst/best/diff/mean):
#     iPhone_charge: worst 21.95, best 1545.62, diff 22.26, mean 95.19
#     MacBook_charge: worst 117.06, best 8243.33, diff 118.74, mean 507.67
#     wifi_router_24h: worst 351.17, best 24729.99, diff 356.23, mean 1523.01
#     streaming_1hr: worst 877.92, best 61824.97, diff 890.56, mean 3807.53
#     google_search: worst 0.44, best 30.91, diff 0.45, mean 1.90
#     kettle: worst 109.74, best 7728.12, diff 111.32, mean 475.94
#     shower: worst 2311.85, best 162805.75, diff 2345.15, mean 10026.48
#
# -- Scenario: By config_name details --
# Config: A1_Single_GPU → 0.00001 kWh per response
#     iPhone_charge: 1545.62 responses
#     MacBook_charge: 8243.33 responses
#     wifi_router_24h: 24729.99 responses
#     streaming_1hr: 61824.97 responses
#     google_search: 30.91 responses
#     kettle: 7728.12 responses
#     shower: 162805.75 responses
# Config: A2_2_GPU → 0.00003 kWh per response
#     iPhone_charge: 451.04 responses
#     MacBook_charge: 2405.55 responses
#     wifi_router_24h: 7216.64 responses
#     streaming_1hr: 18041.59 responses
#     google_search: 9.02 responses
#     kettle: 2255.20 responses
#     shower: 47509.52 responses
# Config: A3_Quantisation_Focus → 0.00001 kWh per response
#     iPhone_charge: 1407.17 responses
#     MacBook_charge: 7504.88 responses
#     wifi_router_24h: 22514.65 responses
#     streaming_1hr: 56286.61 responses
#     google_search: 28.14 responses
#     kettle: 7035.83 responses
#     shower: 148221.42 responses
# Config: A4_Parallel_Exploit → 0.00007 kWh per response
#     iPhone_charge: 225.08 responses
#     MacBook_charge: 1200.42 responses
#     wifi_router_24h: 3601.26 responses
#     streaming_1hr: 9003.15 responses
#     google_search: 4.50 responses
#     kettle: 1125.39 responses
#     shower: 23708.31 responses
# Config: R1_Ultralow_SingleGPU_Greedy → 0.00025 kWh per response
#     iPhone_charge: 59.38 responses
#     MacBook_charge: 316.69 responses
#     wifi_router_24h: 950.07 responses
#     streaming_1hr: 2375.16 responses
#     google_search: 1.19 responses
#     kettle: 296.90 responses
#     shower: 6254.60 responses
# Config: R2_Ultralow_DualGPU_TopP → 0.00068 kWh per response
#     iPhone_charge: 21.95 responses
#     MacBook_charge: 117.06 responses
#     wifi_router_24h: 351.17 responses
#     streaming_1hr: 877.92 responses
#     google_search: 0.44 responses
#     kettle: 109.74 responses
#     shower: 2311.85 responses
# Config: R5_Tail_SingleGPU_Greedy → 0.00005 kWh per response
#     iPhone_charge: 278.46 responses
#     MacBook_charge: 1485.14 responses
#     wifi_router_24h: 4455.42 responses
#     streaming_1hr: 11138.54 responses
#     google_search: 5.57 responses
#     kettle: 1392.32 responses
#     shower: 29331.50 responses
# Config: R6_Tail_DualGPU_TopP → 0.00015 kWh per response
#     iPhone_charge: 99.68 responses
#     MacBook_charge: 531.63 responses
#     wifi_router_24h: 1594.89 responses
#     streaming_1hr: 3987.23 responses
#     google_search: 1.99 responses
#     kettle: 498.40 responses
#     shower: 10499.70 responses
#
# -- Scenario: Group Realistic (4 configs) --
# Mean kWh per response: 0.00029
#     iPhone_charge: 52.61 responses
#     MacBook_charge: 280.60 responses
#     wifi_router_24h: 841.81 responses
#     streaming_1hr: 2104.53 responses
#     google_search: 1.05 responses
#     kettle: 263.07 responses
#     shower: 5541.93 responses
#
# -- Scenario: Group Artificial (4 configs) --
# Mean kWh per response: 0.00003
#     iPhone_charge: 498.90 responses
#     MacBook_charge: 2660.81 responses
#     wifi_router_24h: 7982.42 responses
#     streaming_1hr: 19956.04 responses
#     google_search: 9.98 responses
#     kettle: 2494.50 responses
#     shower: 52550.90 responses
#
# -- Scenario: Realistic vs Artificial --
# Realistic mean: 0.00029 kWh, Artificial mean: 0.00003 kWh
# Difference: 0.00026 kWh, Ratio: 9.48x
#     iPhone_charge: Realistic 52.61, Artificial 498.90, Diff 58.82
#     MacBook_charge: Realistic 280.60, Artificial 2660.81, Diff 313.68
#     wifi_router_24h: Realistic 841.81, Artificial 7982.42, Diff 941.05
#     streaming_1hr: Realistic 2104.53, Artificial 19956.04, Diff 2352.64
#     google_search: Realistic 1.05, Artificial 9.98, Diff 1.18
#     kettle: Realistic 263.07, Artificial 2494.50, Diff 294.08
#     shower: Realistic 5541.93, Artificial 52550.90, Diff 6195.27
#
# === Model: Llama-3.2-3B ===
# -- Scenario: Full config means (8 configs) --
# Overall ratio (max/min): 72.97
# # responses to match appliance (worst/best/diff/mean):
#     iPhone_charge: worst 10.42, best 760.41, diff 10.57, mean 47.18
#     MacBook_charge: worst 55.58, best 4055.54, diff 56.35, mean 251.63
#     wifi_router_24h: worst 166.74, best 12166.63, diff 169.06, mean 754.90
#     streaming_1hr: worst 416.85, best 30416.59, diff 422.65, mean 1887.26
#     google_search: worst 0.21, best 15.21, diff 0.21, mean 0.94
#     kettle: worst 52.11, best 3802.07, diff 52.83, mean 235.91
#     shower: worst 1097.72, best 80097.01, diff 1112.97, mean 4969.78
#
# -- Scenario: Without outlier configs (8 configs) --
# Overall ratio (max/min): 72.97
# # responses to match appliance (worst/best/diff/mean):
#     iPhone_charge: worst 10.42, best 760.41, diff 10.57, mean 47.18
#     MacBook_charge: worst 55.58, best 4055.54, diff 56.35, mean 251.63
#     wifi_router_24h: worst 166.74, best 12166.63, diff 169.06, mean 754.90
#     streaming_1hr: worst 416.85, best 30416.59, diff 422.65, mean 1887.26
#     google_search: worst 0.21, best 15.21, diff 0.21, mean 0.94
#     kettle: worst 52.11, best 3802.07, diff 52.83, mean 235.91
#     shower: worst 1097.72, best 80097.01, diff 1112.97, mean 4969.78
#
# -- Scenario: By config_name details --
# Config: A1_Single_GPU → 0.00002 kWh per response
#     iPhone_charge: 760.41 responses
#     MacBook_charge: 4055.54 responses
#     wifi_router_24h: 12166.63 responses
#     streaming_1hr: 30416.59 responses
#     google_search: 15.21 responses
#     kettle: 3802.07 responses
#     shower: 80097.01 responses
# Config: A2_2_GPU → 0.00007 kWh per response
#     iPhone_charge: 202.38 responses
#     MacBook_charge: 1079.37 responses
#     wifi_router_24h: 3238.12 responses
#     streaming_1hr: 8095.29 responses
#     google_search: 4.05 responses
#     kettle: 1011.91 responses
#     shower: 21317.60 responses
# Config: A3_Quantisation_Focus → 0.00002 kWh per response
#     iPhone_charge: 675.37 responses
#     MacBook_charge: 3601.97 responses
#     wifi_router_24h: 10805.91 responses
#     streaming_1hr: 27014.77 responses
#     google_search: 13.51 responses
#     kettle: 3376.85 responses
#     shower: 71138.91 responses
# Config: A4_Parallel_Exploit → 0.00017 kWh per response
#     iPhone_charge: 90.22 responses
#     MacBook_charge: 481.16 responses
#     wifi_router_24h: 1443.49 responses
#     streaming_1hr: 3608.71 responses
#     google_search: 1.80 responses
#     kettle: 451.09 responses
#     shower: 9502.95 responses
# Config: R1_Ultralow_SingleGPU_Greedy → 0.00049 kWh per response
#     iPhone_charge: 30.80 responses
#     MacBook_charge: 164.28 responses
#     wifi_router_24h: 492.84 responses
#     streaming_1hr: 1232.10 responses
#     google_search: 0.62 responses
#     kettle: 154.01 responses
#     shower: 3244.53 responses
# Config: R2_Ultralow_DualGPU_TopP → 0.00144 kWh per response
#     iPhone_charge: 10.42 responses
#     MacBook_charge: 55.58 responses
#     wifi_router_24h: 166.74 responses
#     streaming_1hr: 416.85 responses
#     google_search: 0.21 responses
#     kettle: 52.11 responses
#     shower: 1097.72 responses
# Config: R5_Tail_SingleGPU_Greedy → 0.00009 kWh per response
#     iPhone_charge: 176.30 responses
#     MacBook_charge: 940.28 responses
#     wifi_router_24h: 2820.85 responses
#     streaming_1hr: 7052.13 responses
#     google_search: 3.53 responses
#     kettle: 881.52 responses
#     shower: 18570.61 responses
# Config: R6_Tail_DualGPU_TopP → 0.00025 kWh per response
#     iPhone_charge: 60.08 responses
#     MacBook_charge: 320.45 responses
#     wifi_router_24h: 961.35 responses
#     streaming_1hr: 2403.38 responses
#     google_search: 1.20 responses
#     kettle: 300.42 responses
#     shower: 6328.91 responses
#
# -- Scenario: Group Realistic (4 configs) --
# Mean kWh per response: 0.00057
#     iPhone_charge: 26.54 responses
#     MacBook_charge: 141.53 responses
#     wifi_router_24h: 424.58 responses
#     streaming_1hr: 1061.45 responses
#     google_search: 0.53 responses
#     kettle: 132.68 responses
#     shower: 2795.16 responses
#
# -- Scenario: Group Artificial (4 configs) --
# Mean kWh per response: 0.00007
#     iPhone_charge: 212.53 responses
#     MacBook_charge: 1133.48 responses
#     wifi_router_24h: 3400.43 responses
#     streaming_1hr: 8501.07 responses
#     google_search: 4.25 responses
#     kettle: 1062.63 responses
#     shower: 22386.14 responses
#
# -- Scenario: Realistic vs Artificial --
# Realistic mean: 0.00057 kWh, Artificial mean: 0.00007 kWh
# Difference: 0.00049 kWh, Ratio: 8.01x
#     iPhone_charge: Realistic 26.54, Artificial 212.53, Diff 30.32
#     MacBook_charge: Realistic 141.53, Artificial 1133.48, Diff 161.72
#     wifi_router_24h: Realistic 424.58, Artificial 3400.43, Diff 485.16
#     streaming_1hr: Realistic 1061.45, Artificial 8501.07, Diff 1212.89
#     google_search: Realistic 0.53, Artificial 4.25, Diff 0.61
#     kettle: Realistic 132.68, Artificial 1062.63, Diff 151.61
#     shower: Realistic 2795.16, Artificial 22386.14, Diff 3193.96

# %% [markdown]
# # Artifical vs realistic

# %%
from scripts.f_scenario_analysis import artificial_v_realistic
artificial_v_realistic(df)
# Out:
# --- Llama-3.2-1B (raw data) ---
# Realistic mean   : 0.00029 kWh/resp
# Artificial mean  : 0.00003 kWh/resp
# - Abs diff (A−R) : -0.00026 kWh
# - Ratio (R/A)    : 9.48×
# - % reduction    : -848.24%
#
# --- Llama-3.2-1B (outliers removed (1.5×IQR)) ---
# Realistic mean   : 0.00015 kWh/resp
# Artificial mean  : 0.00003 kWh/resp
# - Abs diff (A−R) : -0.00012 kWh
# - Ratio (R/A)    : 5.07×
# - % reduction    : -406.62%
#
# --- Llama-3.2-3B (raw data) ---
# Realistic mean   : 0.00057 kWh/resp
# Artificial mean  : 0.00007 kWh/resp
# - Abs diff (A−R) : -0.00049 kWh
# - Ratio (R/A)    : 8.01×
# - % reduction    : -700.89%
#
# --- Llama-3.2-3B (outliers removed (1.5×IQR)) ---
# Realistic mean   : 0.00027 kWh/resp
# Artificial mean  : 0.00007 kWh/resp
# - Abs diff (A−R) : -0.00020 kWh
# - Ratio (R/A)    : 3.88×
# - % reduction    : -288.07%

# %% [markdown]
# # Within-realistic

# %%
from scripts.f_scenario_analysis import within_realistic
within_realistic(df)
# Out:
# *** Llama-3.2-1B (Realistic — raw data) ***
# Worst (max): R2_Ultralow_DualGPU_TopP @ 0.00068 kWh
# Best  (min): R5_Tail_SingleGPU_Greedy @ 0.00005 kWh
# - Abs diff  : 0.00063 kWh
# - % reduction: 92.12%
#
# *** Llama-3.2-1B (Realistic — outliers removed (1.5×IQR)) ***
# Worst (max): R1_Ultralow_SingleGPU_Greedy @ 0.00025 kWh
# Best  (min): R5_Tail_SingleGPU_Greedy @ 0.00005 kWh
# - Abs diff  : 0.00020 kWh
# - % reduction: 78.68%
#
# *** Llama-3.2-3B (Realistic — raw data) ***
# Worst (max): R2_Ultralow_DualGPU_TopP @ 0.00144 kWh
# Best  (min): R5_Tail_SingleGPU_Greedy @ 0.00009 kWh
# - Abs diff  : 0.00135 kWh
# - % reduction: 94.09%
#
# *** Llama-3.2-3B (Realistic — outliers removed (1.5×IQR)) ***
# Worst (max): R1_Ultralow_SingleGPU_Greedy @ 0.00049 kWh
# Best  (min): R5_Tail_SingleGPU_Greedy @ 0.00009 kWh
# - Abs diff  : 0.00040 kWh
# - % reduction: 82.53%
